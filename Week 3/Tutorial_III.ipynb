# %%
# %pip install Crystals
# Out:
# Collecting Crystals
#   Downloading crystals-1.6.2-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy<2,>=1.20 in c:\users\pugaz\anaconda31\lib\site-packages (from Crystals) (1.26.4)
# Collecting spglib<3,>=1.15 (from Crystals)
#   Downloading spglib-2.5.0-cp311-cp311-win_amd64.whl.metadata (4.2 kB)
# Collecting pycifrw<5,>=4.4.1 (from Crystals)
#   Downloading PyCifRW-4.4.6.tar.gz (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 13.1 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: requests<3,>=2 in c:\users\pugaz\anaconda31\lib\site-packages (from Crystals) (2.31.0)
# Requirement already satisfied: ply in c:\users\pugaz\anaconda31\lib\site-packages (from pycifrw<5,>=4.4.1->Crystals) (3.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pugaz\anaconda31\lib\site-packages (from requests<3,>=2->Crystals) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pugaz\anaconda31\lib\site-packages (from requests<3,>=2->Crystals) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pugaz\anaconda31\lib\site-packages (from requests<3,>=2->Crystals) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pugaz\anaconda31\lib\site-packages (from requests<3,>=2->Crystals) (2024.2.2)
# Downloading crystals-1.6.2-py3-none-any.whl (257 kB)
# Downloading spglib-2.5.0-cp311-cp311-win_amd64.whl (300 kB)
# Building wheels for collected packages: pycifrw
#   Building wheel for pycifrw (pyproject.toml): started
#   Building wheel for pycifrw (pyproject.toml): finished with status 'done'
#   Created wheel for pycifrw: filename=PyCifRW-4.4.6-cp311-cp311-win_amd64.whl size=142323 sha256=53bafc83e91709e2ef8b57124cac0c77e2a1515efefdabd093226159a99179d1
#   Stored in directory: c:\users\pugaz\appdata\local\pip\cache\wheels\cd\64\1c\f31c936990ff5d289670c84dd270b89719fc39006b8151e8b7
# Successfully built pycifrw
# Installing collected packages: spglib, pycifrw, Crystals
# Successfully installed Crystals-1.6.2 pycifrw-4.4.6 spglib-2.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install PyCrystallography
# Out:
# Collecting PyCrystallography
#   Downloading PyCrystallography-0.2.1-py3-none-any.whl (32 kB)
# Requirement already satisfied: matplotlib>=3.3.2 in c:\users\pugaz\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from PyCrystallography) (3.4.3)
# Requirement already satisfied: imageio>=2.9.0 in c:\users\pugaz\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from PyCrystallography) (2.22.1)
# Requirement already satisfied: numpy>=1.19.2 in c:\users\pugaz\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from PyCrystallography) (1.22.0)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\pugaz\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from imageio>=2.9.0->PyCrystallography) (8.3.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\pugaz\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib>=3.3.2->PyCrystallography) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pugaz\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib>=3.3.2->PyCrystallography) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\pugaz\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib>=3.3.2->PyCrystallography) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\pugaz\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib>=3.3.2->PyCrystallography) (3.0.4)
# Requirement already satisfied: six>=1.5 in c:\users\pugaz\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.2->PyCrystallography) (1.16.0)
# Installing collected packages: PyCrystallography
# Successfully installed PyCrystallography-0.2.1
#
# [notice] A new release of pip available: 22.2 -> 24.2
# [notice] To update, run: C:\Users\pugaz\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import PyCrystallography

# %%
import sys
sys.path.append('/path/to/PyCrystallography')

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from PyCrystallography.geometry import *
from PyCrystallography import stereographic_projection

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from PyCrystallography.geometry import *

# %%
fig = plt.figure(0,figsize=[8,8])
ax = fig.add_subplot(111,projection='3d')
faces = tetrakis(ax,4,1)
plt.show()

# %%
points=normal_points(ax,faces,5)
plt.show()

# %%
Stereographic_projection(points,5,'dont_save')
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from PyCrystallography.geometry import *
from PyCrystallography import stereographic_projection

# %%
fig = plt.figure(0,figsize=[8,8])
ax = fig.add_subplot(111,projection='3d')
faces = pyramid(ax,1,0.5,3)
points=normal_points(ax,faces,1)
Stereographic_projection(ax,points,1,'stereographic_projection_pyramid')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19212/3636380108.py in <module>
#       3 faces = pyramid(ax,1,0.5,3)
#       4 points=normal_points(ax,faces,1)
# ----> 5 Stereographic_projection(ax,points,1,'stereographic_projection_pyramid')
#       6 plt.show()
#
# TypeError: Stereographic_projection() takes 3 positional arguments but 4 were given
